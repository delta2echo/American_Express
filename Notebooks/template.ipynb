# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/"

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=13bjrheeOZn5XH1t0piIo1YnhHm7tB8fw' -O kaggle.json
# Out:
# --2022-05-28 17:39:08--  https://docs.google.com/uc?export=download&id=13bjrheeOZn5XH1t0piIo1YnhHm7tB8fw
# Resolving docs.google.com (docs.google.com)... 173.194.213.138, 173.194.213.139, 173.194.213.113, ...
# Connecting to docs.google.com (docs.google.com)|173.194.213.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5e7idplnefjrf8enbgonusbjppjl24fn/1653759525000/09813374055824009512/*/13bjrheeOZn5XH1t0piIo1YnhHm7tB8fw?e=download [following]
# ...
# --2022-05-28 17:39:08--  https://doc-10-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5e7idplnefjrf8enbgonusbjppjl24fn/1653759525000/09813374055824009512/*/13bjrheeOZn5XH1t0piIo1YnhHm7tB8fw?e=download
# Resolving doc-10-7c-docs.googleusercontent.com (doc-10-7c-docs.googleusercontent.com)... 108.177.11.132, 2607:f8b0:400c:c01::84
# ...

# %%
# !kaggle competitions download -c amex-default-prediction
# Out:
# ...
# 100% 20.5G/20.5G [01:51<00:00, 219MB/s]
# 100% 20.5G/20.5G [01:51<00:00, 197MB/s]

# %%
# !wget https://raw.githubusercontent.com/delta2echo/American_Express/main/Scripts/helper_functions.py
# Out:
# --2022-05-28 18:57:17--  https://raw.githubusercontent.com/delta2echo/American_Express/main/Scripts/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 549 [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]     549  --.-KB/s    in 0s
#
# 2022-05-28 18:57:17 (27.7 MB/s) - ‘helper_functions.py’ saved [549/549]

# %%
from helper_functions import unzip_files

# %%
unzip_files('amex-default-prediction.zip')
